# %%
import pandas as pd
import sys
sys.path.append('../')
sys.path.append('../../nfldb')
import tasks.base as base
import tasks.dvoa_crap as dvoa
import numpy as np
# Out:
#   down   yardline  yards_to_go  n  fantasy_points
# 0    1   midfield         long  1            0.00
# 1    3    redzone  really_long  1            0.28
# 2    2   midfield  really_long  1            1.00
# 3    3    goaline        short  1            4.08
# 4    2    goaline        short  1            0.00
# 5    3    redzone       medium  1            0.00
# 6    1    redzone         long  1            0.00
# 7    1   midfield         long  1            0.64
# 8    1   midfield         long  1            0.00
# 9    1  touchback         long  1            0.60

# %%
df.groupby(['down', 'yardline', 'yards_to_go']).agg({'n': np.sum, 'fantasy_points': np.sum})
# Out:
#                             fantasy_points  n
# down yardline  yards_to_go
# 1    midfield  long                   0.64  3
#      redzone   long                   0.00  1
#      touchback long                   0.60  1
# 2    goaline   short                  0.00  1
#      midfield  really_long            1.00  1
# 3    goaline   short                  4.08  1
#      redzone   medium                 0.00  1
#                really_long            0.28  1
